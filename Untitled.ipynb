# %%
! python generate_fingerprint.py
# Out:
# Using TensorFlow backend.
# Loaded expectmax lib for 2048: /home/ubuntu/2048-api/game2048/expectimax/bin/2048.so
# Move 2: result 1591360.625000: eval'd 14664 moves (530 cache hits, 328 cache size) in 0.00 seconds (maxdepth=3)
# Move 0: result 1590618.000000: eval'd 33992 moves (921 cache hits, 545 cache size) in 0.00 seconds (maxdepth=3)
# Move 1: result 1592914.375000: eval'd 33736 moves (995 cache hits, 531 cache size) in 0.00 seconds (maxdepth=3)
# Move 3: result 1583041.875000: eval'd 14760 moves (487 cache hits, 340 cache size) in 0.00 seconds (maxdepth=3)
# Move 0: result 1542905.750000: eval'd 48848 moves (1625 cache hits, 643 cache size) in 0.00 seconds (maxdepth=3)
# Move 2: result 1541277.000000: eval'd 38008 moves (1377 cache hits, 540 cache size) in 0.00 seconds (maxdepth=3)
# Move 1: result 1563977.750000: eval'd 47536 moves (1709 cache hits, 615 cache size) in 0.00 seconds (maxdepth=3)
# ...
